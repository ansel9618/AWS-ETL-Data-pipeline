# %%
#step1) install the below library
#!pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------- ----------------- 143.4/252.0 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 252.0/252.0 kB 3.8 MB/s eta 0:00:00
# ...

# %%
#step 2) import the necessary credentials
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#step3) mentioning the spotify client credentials
client_credentials_manager = SpotifyClientCredentials(client_id="2328a50632154d7fa2590fe168f64089", 
                            client_secret="c93e9d9f4b9c49d0a541ebce62ab8024")

# %%
#step4) creating spotify object so that we can extract data from the api

sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#step 4
#our objective is to extract the top 100 songs every day at a specific time and put it in a database
playlist_link = "https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
#step5
#we'll split the link so as to get the right data -->5ABHKGoOzxkaa28ttQV9sE

playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '5ABHKGoOzxkaa28ttQV9sE']

# %%
playlist_URL=playlist_link.split("/")[-1]

# %%
sp.playlist_tracks(playlist_URL)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5ABHKGoOzxkaa28ttQV9sE/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-15T21:57:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#     'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#     'id': 'jonathan.holgersson',
#     'type': 'user',
#     'uri': 'spotify:user:jonathan.holgersson'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
# ...

# %%
data = sp.playlist_tracks(playlist_URL)

# %%
# once we get the data we need to properly extract the data such that its in the format that we need

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 14

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
#once the required data is extrated we can need to create a dictionary to store the element
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    #print(album_id) #here we are looping through the entire json data and accessing the id

    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                    'total_tracks':album_total_tracks,'url':album_url}
    #print(album_element) # to list out the dictionary
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '35s58BRTGAEWztPo9WqCIs',
#   'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#   'release_date': '2018-12-14',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#  {'album_id': '09fggMHib4YkOtwQNXEBII',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
# ...

# %%
#we can also extract data from artists

data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]

# %%
#here one song can have multiple artists

data['items'][4]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#   'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#   'id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'name': 'Daft Punk',
#   'type': 'artist',
#   'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
#thus we need to tacle the above isuue also
#here within the track we are trying to extract the data inside the track which is artist data

artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            #print(value['artists'])
            for artist in value['artists']:
                #print(artist['id'])
                for artists in value['artists']:
                    artist_dict = {'artists_id':artist['id'],
                                   'artists_name':artist['name'],
                                   'external_url':artist['href']
                                  }
                    artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artists_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artists_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artists_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artists_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artists_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artists_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artists_id': '246dkjvS1zLTtiykXe5h60',
#   'artists_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artists_id': '246dkjvS1zLTtiykXe5h60',
#   'artists_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artists_id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'artists_name': 'Swae Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'},
# ...

# %%
#songlist

song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    #print(song_name)

    song_element = {'song_id':song_id,
                    'song_name':song_name,
                    'duration_ms':song_duration,
                    'url':song_url,
                    'popularity':song_popularity,
                    'song_added':song_added,
                    'album_id':album_id,
                    'artist_id':artist_id
                    }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration_ms': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 91,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration_ms': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 87,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
#   'song_name': 'Someone You Loved',
#   'duration_ms': 182160,
#   'url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf',
#   'popularity': 90,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '5658aM19fA3JVwTK6eQX70',
#   'artist_id': '4GNC7GD6oZMSxPGyXy4MNB'},
# ...

# %%
## once the proper data is retrieved we can convert it tinto a proper dataframe

import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id  ...                                                url
# 0  4yP0hdKOZPNshxUOjY0cZj  ...  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  3T4tUhGYeRNVUGevb0wThu  ...  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  5658aM19fA3JVwTK6eQX70  ...  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3  35s58BRTGAEWztPo9WqCIs  ...  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4  09fggMHib4YkOtwQNXEBII  ...  https://open.spotify.com/album/09fggMHib4YkOtw...
#
# [5 rows x 5 columns]

# %%
album_df.info()
#its in object state
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
#dropping duplicates
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df
# Out:
#                   album_id  ...                                                url
# 0   4yP0hdKOZPNshxUOjY0cZj  ...  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1   3T4tUhGYeRNVUGevb0wThu  ...  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2   5658aM19fA3JVwTK6eQX70  ...  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3   35s58BRTGAEWztPo9WqCIs  ...  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4   09fggMHib4YkOtwQNXEBII  ...  https://open.spotify.com/album/09fggMHib4YkOtw...
# ..                     ...  ...                                                ...
# 95  1NAmidJlEaVgA3MpcPFYGq  ...  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 96  5W9OT0a5iZlBr83a9WMKFY  ...  https://open.spotify.com/album/5W9OT0a5iZlBr83...
# 97  7qVkGVpcHzaXBT3JENXOq8  ...  https://open.spotify.com/album/7qVkGVpcHzaXBT3...
# 98  3vLaOYCNCzngDf8QdBg2V1  ...  https://open.spotify.com/album/3vLaOYCNCzngDf8...
# ...

# %%
#same to be done for artist_df and song_list

artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = album_df.drop_duplicates(subset=['album_id'])
# Out:
#                   album_id  ...                                                url
# 0   4yP0hdKOZPNshxUOjY0cZj  ...  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1   3T4tUhGYeRNVUGevb0wThu  ...  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2   5658aM19fA3JVwTK6eQX70  ...  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3   35s58BRTGAEWztPo9WqCIs  ...  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4   09fggMHib4YkOtwQNXEBII  ...  https://open.spotify.com/album/09fggMHib4YkOtw...
# ..                     ...  ...                                                ...
# 95  1NAmidJlEaVgA3MpcPFYGq  ...  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 96  5W9OT0a5iZlBr83a9WMKFY  ...  https://open.spotify.com/album/5W9OT0a5iZlBr83...
# 97  7qVkGVpcHzaXBT3JENXOq8  ...  https://open.spotify.com/album/7qVkGVpcHzaXBT3...
# 98  3vLaOYCNCzngDf8QdBg2V1  ...  https://open.spotify.com/album/3vLaOYCNCzngDf8...
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df
# Out:
#                    song_id                                      song_name  ...                album_id               artist_id
# 0   0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights  ...  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1   7qiZfU4dY1lWllzX7mPBI3                                   Shape of You  ...  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# 2   7qEHsqek33rTcFNT9PFqLf                              Someone You Loved  ...  5658aM19fA3JVwTK6eQX70  4GNC7GD6oZMSxPGyXy4MNB
# 3   3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse  ...  35s58BRTGAEWztPo9WqCIs  0LyfQWJT6nXafLPZqxe9Of
# 4   5aAx2yezTd8zXrkmtKl66Z                                        Starboy  ...  09fggMHib4YkOtwQNXEBII  1Xyo4u8uXC1ZmMpatF05PJ
# ..                     ...                                            ...  ...                     ...                     ...
# ...

# %%
#we need to make the time in right format
album_df
# Out:
#                   album_id  ...                                                url
# 0   4yP0hdKOZPNshxUOjY0cZj  ...  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1   3T4tUhGYeRNVUGevb0wThu  ...  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2   5658aM19fA3JVwTK6eQX70  ...  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3   35s58BRTGAEWztPo9WqCIs  ...  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4   09fggMHib4YkOtwQNXEBII  ...  https://open.spotify.com/album/09fggMHib4YkOtw...
# ..                     ...  ...                                                ...
# 95  1NAmidJlEaVgA3MpcPFYGq  ...  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 96  5W9OT0a5iZlBr83a9WMKFY  ...  https://open.spotify.com/album/5W9OT0a5iZlBr83...
# 97  7qVkGVpcHzaXBT3JENXOq8  ...  https://open.spotify.com/album/7qVkGVpcHzaXBT3...
# 98  3vLaOYCNCzngDf8QdBg2V1  ...  https://open.spotify.com/album/3vLaOYCNCzngDf8...
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'],format='ISO8601')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      93 non-null     object
#  1   name          93 non-null     object
#  2   release_date  93 non-null     datetime64[ns]
#  3   total_tracks  93 non-null     int64
#  4   url           93 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.4+ KB

# %%
album_df
# Out:
#                   album_id  ...                                                url
# 0   4yP0hdKOZPNshxUOjY0cZj  ...  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1   3T4tUhGYeRNVUGevb0wThu  ...  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2   5658aM19fA3JVwTK6eQX70  ...  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3   35s58BRTGAEWztPo9WqCIs  ...  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4   09fggMHib4YkOtwQNXEBII  ...  https://open.spotify.com/album/09fggMHib4YkOtw...
# ..                     ...  ...                                                ...
# 95  1NAmidJlEaVgA3MpcPFYGq  ...  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 96  5W9OT0a5iZlBr83a9WMKFY  ...  https://open.spotify.com/album/5W9OT0a5iZlBr83...
# 97  7qVkGVpcHzaXBT3JENXOq8  ...  https://open.spotify.com/album/7qVkGVpcHzaXBT3...
# 98  3vLaOYCNCzngDf8QdBg2V1  ...  https://open.spotify.com/album/3vLaOYCNCzngDf8...
# ...

# %%
##for song added
song_df.head()
# Out:
#                   song_id                                      song_name  ...                album_id               artist_id
# 0  0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights  ...  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  7qiZfU4dY1lWllzX7mPBI3                                   Shape of You  ...  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# 2  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved  ...  5658aM19fA3JVwTK6eQX70  4GNC7GD6oZMSxPGyXy4MNB
# 3  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse  ...  35s58BRTGAEWztPo9WqCIs  0LyfQWJT6nXafLPZqxe9Of
# 4  5aAx2yezTd8zXrkmtKl66Z                                        Starboy  ...  09fggMHib4YkOtwQNXEBII  1Xyo4u8uXC1ZmMpatF05PJ
#
# [5 rows x 8 columns]

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'],format='ISO8601')
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
#so with this we have extracted the data to the form we need and now we will try to deploy it in cloud
